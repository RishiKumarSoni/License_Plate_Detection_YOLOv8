# %%
import os

from ultralytics import YOLO
import cv2

# %%
# %%time
# Load a model
model = YOLO(model_path)  # load a custom model

threshold = 0.5

while ret:

    results = model(frame)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    out.write(frame)
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 151.7ms
# Speed: 16.2ms preprocess, 151.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.7ms
# Speed: 4.3ms preprocess, 153.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 112.8ms
# Speed: 5.5ms preprocess, 112.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 91.8ms
# Speed: 3.9ms preprocess, 91.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 113.6ms
# Speed: 3.6ms preprocess, 113.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 113.4ms
# Speed: 5.0ms preprocess, 113.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.0ms
# Speed: 4.0ms preprocess, 87.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
# %%time

from ultralytics import YOLO
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %%time

model = YOLO(r"C:\Users\cdac\Documents\ANPR\runs\detect\train\weights\best.pt")
# Out:
# CPU times: total: 328 ms
# Wall time: 4.4 s

# %%
# %%time 

results = model(source=r"C:\Users\cdac\Documents\ANPR\sample\r1.mp4", show=True, conf=0.5, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/366) C:\Users\cdac\Documents\ANPR\sample\r1.mp4: 640x384 (no detections), 280.9ms
# video 1/1 (2/366) C:\Users\cdac\Documents\ANPR\sample\r1.mp4: 640x384 (no detections), 157.0ms
# video 1/1 (3/366) C:\Users\cdac\Documents\ANPR\sample\r1.mp4: 640x384 (no detections), 157.1ms
# video 1/1 (4/366) C:\Users\cdac\Documents\ANPR\sample\r1.mp4: 640x384 (no detections), 208.6ms
# ...

# %%
# %%time 

results = model(source=r"C:\Users\cdac\Documents\ANPR\sample\r2.mp4", show=True, conf=0.5, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/497) C:\Users\cdac\Documents\ANPR\sample\r2.mp4: 640x384 (no detections), 167.7ms
# video 1/1 (2/497) C:\Users\cdac\Documents\ANPR\sample\r2.mp4: 640x384 (no detections), 160.2ms
# video 1/1 (3/497) C:\Users\cdac\Documents\ANPR\sample\r2.mp4: 640x384 (no detections), 143.8ms
# video 1/1 (4/497) C:\Users\cdac\Documents\ANPR\sample\r2.mp4: 640x384 (no detections), 116.5ms
# ...

# %%
# VIDEOS_DIR = os.path.join('.', 'videos')

# video_path = os.path.join(VIDEOS_DIR, 'traffic.mp4')
# video_path_out = '{}_out.mp4'.format(video_path)

# video_path = r"\traffic.mp4"

# %%
# cap = cv2.VideoCapture(video_path)
# cap = cv2.VideoCapture('traffic.mp4')
# video_path_out = r"C:/Users/cdac/Documents/ANPR/"

# %%
# print(cap)
# Out:
# < cv2.VideoCapture 00000228AC960FD0>

# %%
# ret, frame = cap.read()
# print(ret)
# print(frame)
# H, W, _ = frame.shape

# out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))
# model_path = os.path.join('.', 'runs', 'detect', 'train', 'weights', 'last.pt')
